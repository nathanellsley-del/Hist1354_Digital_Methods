# %% [markdown]
# <a href="https://colab.research.google.com/github/nathanellsley-del/Hist1354_Digital_Methods/blob/main/Dataset_1_Vietnam_Enlisted_Notebooks_raw_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
file_path = ('/HIST 1534 Mile Stone 1 Dataset - Vietnam_Veterans_by_State.csv')

df = pd.read_csv(file_path)
df.head(100)
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                                             Alabama
# 2                                              Alaska
# 3                                             Arizona
# 4                                            Arkansas
# ..                                                ...
# 56   'N' means that the data for this geographic a...
# 57  * A disability exists when an individual’s bod...
# 58  ▪ This number was omited because fewer than 30...
# 59                                                NaN
# 60  Source: https://catalog.data.gov/dataset/vietn...
#
#                     Unnamed: 1      Unnamed: 2           Unnamed: 3  \
# 0   Vietnam Veteran Population  Percent Female  Below Poverty Level
# 1                      121,206             3.9                  9.2
# 2                       18,200               ▪                    ▪
# ...
